# %% [markdown]
# # PIPE Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from astropy.io import fits
from astropy.table import Table

# %%
p1 = os.getcwd()
p2 = p1 + '/Data/PIPE/'

# %%
lcim = fits.open(p2 + 'WASP-189_201_im.fits')
lcim_h = lcim[1].header
lcim_h
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  114 / length of dimension 1
# NAXIS2  =                 5397 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   15 / number of table fields
# DATE    = '2021-03-03T07:31:43' / creation time of this HDU
# STAMP   = 'visit_combination 13.1.1' / program creating this HDU
# SVN_REV = '22815   '           / svn revision of the software creating this HDU
# EXTNAME = 'SCI_RAW_Imagette'   / extension name
# SCHEMA  = 'SCI_RAW_Imagette.fsd' / filename of schema defining this data structu
# EXT_VER = '13.1    '           / version of the data structure
# DATA_LVL= 'L0.5    '           / Level of this data product
# ...

# %%
lcim_d = Table.read(lcim[1])
lcim_d
# Out:
# <Table length=5397>
#      MJD_TIME           BJD_TIME      ...     thermFront_2
#        day                day         ...
#      float64            float64       ...       float64
# ------------------ ------------------ ... -------------------
#  58927.11932719212 2458927.6232384266 ...    -12.219970703125
# 58927.119383029596  2458927.623294268 ...  -12.21580555400904
#  58927.11943886706 2458927.6233501094 ... -12.211640405435821
#  58927.11949470454 2458927.6234059506 ...  -12.20747525631986
#  58927.11955054201  2458927.623461792 ... -12.203310107203897
#  58927.11960637948 2458927.6235176334 ... -12.199144958630681
#  58927.11966221695 2458927.6235734746 ... -12.194979809514718
# 58927.119718054426  2458927.623629316 ... -12.190814660398757
#   58927.1197738919 2458927.6236851574 ...  -12.19217515721333
#                ...                ... ...                 ...
#  58927.63978746052 2458928.1437351033 ... -11.765046396442166
# ...

# %%
lcsa = fits.open(p2 + 'WASP-189_201_sa.fits')
lcsa_h = lcsa[1].header
lcsa_h
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   98 / length of dimension 1
# NAXIS2  =                  771 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   13 / number of table fields
# DATE    = '2021-03-03T07:33:10' / creation time of this HDU
# STAMP   = 'main_calibration.py 13.1' / program creating this HDU
# SVN_REV = '22815   '           / svn revision of the software creating this HDU
# EXTNAME = 'SCI_CAL_SubArray'   / extension name
# SCHEMA  = 'SCI_CAL_SubArray.fsd' / filename of schema defining this data structu
# EXT_VER = '13.1    '           / version of the data structure
# DATA_LVL= 'L1      '           / Level of this data product
# ...

# %%
lcsa_d = Table.read(lcsa[1])
lcsa_d
# Out:
# <Table length=771>
#      MJD_TIME           BJD_TIME      ...     thermFront_2
#        day                day         ...
#      float64            float64       ...       float64
# ------------------ ------------------ ... -------------------
#  58927.11949470454 2458927.6234059506 ...    -12.219970703125
#  58927.11988556684   2458927.62379684 ...   -12.1907958984375
# 58927.120276423135  2458927.624187724 ...  -12.20050048828125
#  58927.12066728544  2458927.624578614 ... -12.181060791015625
#  58927.12105814773  2458927.624969504 ...  -12.20050048828125
#  58927.12144900969  2458927.625360393 ...    -12.219970703125
#  58927.12183987799  2458927.625751289 ...  -12.20050048828125
#  58927.12223073993  2458927.626142178 ...    -12.219970703125
#  58927.12262159659 2458927.6265330627 ...  -12.20050048828125
#                ...                ... ...                 ...
#  58927.63660473101  2458928.140552152 ... -11.776519775390625
# ...
